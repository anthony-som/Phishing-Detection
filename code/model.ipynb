# %%
import pandas as pd

train_df = pd.read_csv('../data/train.csv', header=None, dtype={2: str})
test_df = pd.read_csv('../data/test.csv', header=None)

test_df.head(20)
# Out:
#     0                                                  1
# 0   2                       http://minsotc.alania.gov.ru
# 1   2                       http://www.freejavaguide.com
# 2   1  http://yeneliswa.co.za/moods/bankofamerica/7dd...
# 3   2  https://victordahdalehfoundation.com/programme...
# 4   2          http://camphhsi.com/product/list_947.html
# 5   2                      https://www.arkosis.com/about
# 6   2                    https://arujit.github.io/random
# 7   2                 http://abiertomexicanodetenis.com/
# 8   1  http://zonaderegistrosenlineabnweb1.com/BNWeb/...
# 9   1              http://froxhositng.000webhostapp.com/
# 10  1  https://emailupdate.azurewebsites.net/apple/eb...
# 11  2                     https://codesandbox.io/s/2wvzx
# 12  1  https://home-onlineingservice-7c2773.ingress-c...
# 13  1  https://chase-authoririze.serveusers.com/../my...
# 14  2                      https://ohiostatebuckeyes.com
# ...
